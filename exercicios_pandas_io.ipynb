# %% [markdown]
# # Atividade 1 - CSV

# %%
import pandas as pd

# %%
# Verifique se o arquivo CSV está separado por vírgula ou ponto e vírgula.
# A codificação do arquivo é ISO-8859-1.
# As três primeiras linhas linhas do arquivo podem ser desconsideradas, pois o cabeçalho só começa na quarta linha.
# As 9 últimas linhas também podem ser desconsideradas, pois são apenas informações sobre onde os dados foram obtidos.
# Para deletar as últimas linhas é necessário adicionar o parâmetro engine='python'.

url = 'https://raw.githubusercontent.com/alura-cursos/Pandas/main/dados_sus.csv'
dados_sus = pd.read_csv(url, encoding = 'ISO-8859-1', sep = ';', skiprows = 3, skipfooter = 9, engine = 'python')
dados_sus.head()
# Out:
#   Unidade da Federação     2008/Jan     2008/Fev     2008/Mar     2008/Abr  \
# 0             Rondônia   1388528,39   2931283,42   1541682,52   1525314,96
# 1                 Acre    902416,00   1497206,26   1794028,48   1730469,42
# 2             Amazonas   4735529,42   7118990,57   8196635,49   8259378,42
# 3              Roraima    657889,53    777939,31    718688,03    839994,39
# 4                 Pará  18864744,11  19553758,20  21937342,70  20842829,69
#
#       2008/Mai     2008/Jun     2008/Jul     2008/Ago     2008/Set  ...  \
# 0   1645953,84   1406150,68   3065279,01   3231494,61   3117178,63  ...
# 1   1819443,92   1828496,00   2511754,59   2089107,14   2275708,53  ...
# 2   7831399,90   8477273,62   9368858,72   9352532,70   9363099,35  ...
# 3    862347,96    832440,66    996693,09    894271,18    910424,17  ...
# 4  23249952,88  23240687,56  24002223,56  23341218,03  25172261,32  ...
#
#       2020/Jul     2020/Ago     2020/Set     2020/Out     2020/Nov  \
# ...

# %% [markdown]
# # Atividade 2 - XLSX

# %%
#Neste desafio, a sua função é efetuar a leitura desse link do Google Planilhas e depois salvar o DataFrame obtido no formato CSV. Pronto(a) para começar?

#https://docs.google.com/spreadsheets/d/1pvBoLyX8kP0TjtUbadVMGdTl4yzm6bHMThhPiqCVtpw/edit?usp=sharing

# %%
planilha = '1pvBoLyX8kP0TjtUbadVMGdTl4yzm6bHMThhPiqCVtpw'

# %%
url = f'https://docs.google.com/spreadsheets/d/{planilha}/gviz/tq?tqx=out:csv&sheet'

# %%
planilha_co2 = pd.read_csv(url)
planilha_co2.head()
# Out:
#        Country country_code                     Region  \
# 0        Aruba          ABW  Latin America & Caribbean
# 1  Afghanistan          AFG                 South Asia
# 2       Angola          AGO         Sub-Saharan Africa
# 3      Albania          ALB      Europe & Central Asia
# 4      Andorra          AND      Europe & Central Asia
#
#                            Indicator Name           1990         1991  \
# 0  CO2 emissions (metric tons per capita)            NaN          NaN
# 1  CO2 emissions (metric tons per capita)    191.745.115  167.681.579
# 2  CO2 emissions (metric tons per capita)    553.661.955  544.538.649
# 3  CO2 emissions (metric tons per capita)  1.819.541.634  124.281.022
# 4  CO2 emissions (metric tons per capita)  7.521.831.658  723.537.924
#
#           1992           1993           1994           1995  ...  \
# 0          NaN            NaN            NaN            NaN  ...
# 1   95.957.742      8.472.111     75.545.827     68.467.956  ...
# ...

# %%
planilha_co2.to_csv('planilha_co2.csv', index = False)

# %% [markdown]
# # Atividade 3 - JSON

# %%
# O desafio agora é normalizar esse DataFrame, expandindo as colunas address e company em suas respectivas subcolunas para facilitar a visualização e a análise dos dados.

import requests
import json

dados_usuarios = requests.get('https://jsonplaceholder.typicode.com/users')
resultado = json.loads(dados_usuarios.text)

# %%
dados_normalizados = pd.json_normalize(resultado, sep = '_')
dados_normalizados
# Out:
#    id                      name          username                      email  \
# 0   1             Leanne Graham              Bret          Sincere@april.biz
# 1   2              Ervin Howell         Antonette          Shanna@melissa.tv
# 2   3          Clementine Bauch          Samantha         Nathan@yesenia.net
# 3   4          Patricia Lebsack          Karianne  Julianne.OConner@kory.org
# 4   5          Chelsey Dietrich            Kamren   Lucio_Hettinger@annie.ca
# 5   6      Mrs. Dennis Schulist  Leopoldo_Corkery    Karley_Dach@jasper.info
# 6   7           Kurtis Weissnat      Elwyn.Skiles     Telly.Hoeger@billy.biz
# 7   8  Nicholas Runolfsdottir V     Maxime_Nienow       Sherwood@rosamond.me
# 8   9           Glenna Reichert          Delphine    Chaim_McDermott@dana.io
# 9  10        Clementina DuBuque    Moriah.Stanton     Rey.Padberg@karina.biz
#
#                    phone        website     address_street address_suite  \
# ...

# %% [markdown]
# # Atividade 4 = HTML

# %%
# Assim como Vanessa, seu desafio é obter um DataFrame da tabela que contém as informações do número de habitantes de cada país.

# %%
pd.read_html('https://pt.wikipedia.org/wiki/Lista_de_pa%C3%ADses_por_popula%C3%A7%C3%A3o')[0]
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# /tmp/ipython-input-703579826.py in <cell line: 0>()
# ----> 1 pd.read_html('https://pt.wikipedia.org/wiki/Lista_de_pa%C3%ADses_por_popula%C3%A7%C3%A3o')[0]
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/html.py in read_html(io, match, flavor, header, index_col, skiprows, attrs, parse_dates, thousands, encoding, decimal, converters, na_values, keep_default_na, displayed_only, extract_links, dtype_backend, storage_options)
#    1238         )
#    1239
# -> 1240     return _parse(
#    1241         flavor=flavor,
#    1242         io=io,
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/html.py in _parse(flavor, io, match, attrs, encoding, displayed_only, extract_links, storage_options, **kwargs)
#     981
#     982         try:
# --> 983             tables = p.parse_tables()
# ...

# %%
import requests

url = 'https://pt.wikipedia.org/wiki/Lista_de_pa%C3%ADses_por_popula%C3%A7%C3%A3o'
response = requests.get(url)
response.encoding = 'utf-8' # Define a codificação para UTF-8

tabela_paises = pd.read_html(response.text)
display(tabela_paises[0].head())
# Out:
# /tmp/ipython-input-4100308336.py:7: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   tabela_paises = pd.read_html(response.text)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-4100308336.py in <cell line: 0>()
#       5 response.encoding = 'utf-8' # Define a codificação para UTF-8
#       6
# ----> 7 tabela_paises = pd.read_html(response.text)
#       8 display(tabela_paises[0].head())
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/html.py in read_html(io, match, flavor, header, index_col, skiprows, attrs, parse_dates, thousands, encoding, decimal, converters, na_values, keep_default_na, displayed_only, extract_links, dtype_backend, storage_options)
#    1238         )
#    1239
# -> 1240     return _parse(
# ...

# %%
tabela_paises = pd.read_html('https://pt.wikipedia.org/wiki/Lista_de_pa%C3%ADses_por_popula%C3%A7%C3%A3o')[0]
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# /tmp/ipython-input-1493130221.py in <cell line: 0>()
# ----> 1 tabela_paises = pd.read_html('https://pt.wikipedia.org/wiki/Lista_de_pa%C3%ADses_por_popula%C3%A7%C3%A3o')[0]
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/html.py in read_html(io, match, flavor, header, index_col, skiprows, attrs, parse_dates, thousands, encoding, decimal, converters, na_values, keep_default_na, displayed_only, extract_links, dtype_backend, storage_options)
#    1238         )
#    1239
# -> 1240     return _parse(
#    1241         flavor=flavor,
#    1242         io=io,
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/html.py in _parse(flavor, io, match, attrs, encoding, displayed_only, extract_links, storage_options, **kwargs)
#     981
#     982         try:
# --> 983             tables = p.parse_tables()
# ...

# %% [markdown]
# # Atividade 5 - Bancos de dados

# %%
import sqlalchemy
from sqlalchemy import create_engine, MetaData, Table, inspect
from sqlalchemy import text

# %%
engine = create_engine('sqlite:///:memory:')

# %%
url = 'https://raw.githubusercontent.com/alura-cursos/Pandas/main/clientes_banco.csv'

# %%
dados = pd.read_csv(url)
dados
# Out:
#         ID_Cliente  Idade Grau_escolaridade   Estado_civil  Tamanho_familia  \
# 0          5008804     32   Ensino superior  União-estável                2
# 1          5008805     32   Ensino superior  União-estável                2
# 2          5008806     58      Ensino médio         Casado                2
# 3          5008808     52      Ensino médio       Solteiro                1
# 4          5008809     52      Ensino médio       Solteiro                1
# ...            ...    ...               ...            ...              ...
# 438458     6840104     62      Ensino médio     Divorciado                1
# 438459     6840222     43      Ensino médio       Solteiro                1
# 438460     6841878     22   Ensino superior       Solteiro                1
# 438461     6842765     59      Ensino médio         Casado                2
# 438462     6842885     51      Ensino médio         Casado                2
#
# ...

# %%
dados.to_sql('clientes', engine, index = False)
# Out:
# 438463

# %%
inspector = inspect(engine)

# %%
# Atualizar o registro do cliente de ID 6840104 que teve o rendimento anual alterado para 300000.

query = 'UPDATE clientes SET Rendimento_anual = 300000 WHERE ID_Cliente = 6840104'
with engine.connect() as conn:
  result = conn.execute(text(query))
  conn.commit()

# %%
pd.read_sql_table('clientes', engine)
# Out:
#         ID_Cliente  Idade Grau_escolaridade   Estado_civil  Tamanho_familia  \
# 0          5008804     32   Ensino superior  União-estável                2
# 1          5008805     32   Ensino superior  União-estável                2
# 2          5008806     58      Ensino médio         Casado                2
# 3          5008808     52      Ensino médio       Solteiro                1
# 4          5008809     52      Ensino médio       Solteiro                1
# ...            ...    ...               ...            ...              ...
# 438458     6840104     62      Ensino médio     Divorciado                1
# 438459     6840222     43      Ensino médio       Solteiro                1
# 438460     6841878     22   Ensino superior       Solteiro                1
# 438461     6842765     59      Ensino médio         Casado                2
# 438462     6842885     51      Ensino médio         Casado                2
#
# ...

# %%
# Excluir o registro do cliente de ID 5008809, pois essa pessoa não possui mais conta na instituição financeira.

query = 'DELETE FROM clientes WHERE ID_Cliente = 5008809'
with engine.connect() as conn:
  result = conn.execute(text(query))
  conn.commit()

# %%
pd.read_sql_table('clientes', engine)
# Out:
#         ID_Cliente  Idade Grau_escolaridade   Estado_civil  Tamanho_familia  \
# 0          5008804     32   Ensino superior  União-estável                2
# 1          5008805     32   Ensino superior  União-estável                2
# 2          5008806     58      Ensino médio         Casado                2
# 3          5008808     52      Ensino médio       Solteiro                1
# 4          5008810     52      Ensino médio       Solteiro                1
# ...            ...    ...               ...            ...              ...
# 438457     6840104     62      Ensino médio     Divorciado                1
# 438458     6840222     43      Ensino médio       Solteiro                1
# 438459     6841878     22   Ensino superior       Solteiro                1
# 438460     6842765     59      Ensino médio         Casado                2
# 438461     6842885     51      Ensino médio         Casado                2
#
# ...

# %%
# Criar um novo registro de cliente

# %%
query = 'INSERT INTO clientes (ID_Cliente, Idade, Grau_escolaridade,	Estado_civil,	Tamanho_familia,	Categoria_de_renda,	Ocupacao,	Anos_empregado,	Rendimento_anual, Tem_carro,	Moradia)\
  VALUES (6850985, 33, "Doutorado", "Solteiro", 1, "Empregado", "TI", 2, 290000, 0, "Casa/apartamento próprio")'
with engine.connect() as conn:
  result = conn.execute(text(query))
  conn.commit()

# %%
pd.read_sql_table('clientes', engine)
# Out:
#         ID_Cliente  Idade Grau_escolaridade   Estado_civil  Tamanho_familia  \
# 0          5008804     32   Ensino superior  União-estável                2
# 1          5008805     32   Ensino superior  União-estável                2
# 2          5008806     58      Ensino médio         Casado                2
# 3          5008808     52      Ensino médio       Solteiro                1
# 4          5008810     52      Ensino médio       Solteiro                1
# ...            ...    ...               ...            ...              ...
# 438458     6840222     43      Ensino médio       Solteiro                1
# 438459     6841878     22   Ensino superior       Solteiro                1
# 438460     6842765     59      Ensino médio         Casado                2
# 438461     6842885     51      Ensino médio         Casado                2
# 438462     6850985     33         Doutorado       Solteiro                1
#
# ...
